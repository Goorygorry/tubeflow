# %% [markdown]
# ### 🏷️ **Credits & License**
#
# * 🔗 [OmniVoice GitHub Repository](https://github.com/k2-fsa/OmniVoice)
# * 🤗 [OmniVoice on Hugging Face](https://huggingface.co/k2-fsa/OmniVoice)
# * 📄 **License**: Provided under the [Apache License 2.0
# ](https://github.com/k2-fsa/OmniVoice/blob/master/LICENSE)
#
#
#
# ### ⚠️ **Usage Disclaimer**
#
# Use of this voice cloning model is subject to strict ethical and legal standards. By using this tool, you agree **not to** engage in any of the following prohibited activities:
#
# * **Fraud or Deception**: Using cloned voices to create misleading or fraudulent content.
# * **Impersonation**: Replicating someone’s voice without their explicit permission, especially for malicious, harmful, or deceptive purposes.
# * **Illegal Activities**: Employing the model in any manner that violates local, national, or international laws and regulations.
# * **Harmful Content Generation**: Creating offensive, defamatory, or unethical material, including content that spreads misinformation or causes harm.
#
# > ⚖️ **Legal Responsibility**
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
#@title Install OmniVoice
# %cd /content/
# !rm -rf ./omnivoice-colab
# !git clone https://github.com/NeuralFalconYT/omnivoice-colab.git
# %cd ./omnivoice-colab
# !git clone https://github.com/k2-fsa/OmniVoice.git
# !git clone https://github.com/NeuralFalconYT/OmniVoice.git
# !pip install -r colab.txt
# !pip install -r requirements.txt
from IPython.display import clear_output
clear_output()

# %%
#@title Run Gradio APP
# %cd /content/omnivoice-colab
# !python app.py
# Out:
# /content/omnivoice-colab
# Loading model from k2-fsa/OmniVoice to cuda ...
# config.json: 2.24kB [00:00, 6.96MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-05 17:38:51,439 huggingface_hub.utils._http WARNING: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: 100% 2.45G/2.45G [00:23<00:00, 104MB/s]
# Loading weights: 100% 313/313 [00:00<00:00, 349.32it/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 1.57kB [00:00, 14.5kB/s]
# Downloading (incomplete total...):  99% 805M/817M [00:04<00:00, 268MB/s]
# Fetching 13 files: 100% 13/13 [00:04<00:00,  2.63it/s]
# Download complete: : 817MB [00:05, 149MB/s]
# Loading weights: 100% 527/527 [00:00<00:00, 1744.55it/s]
# Model loaded successfully!
# /content/omnivoice-colab/app.py:324: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# /content/omnivoice-colab/app.py:324: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://065134f6d213c99350.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2026-04-05 17:42:11,907 omnivoice.models.omnivoice WARNING: Reference audio is 191.7s long (>20s) and ref_text was provided, so automatic trimming is skipped. A long reference may cause slower generation and degraded quality.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2191, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1698, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2518, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 1002, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/app.py", line 395, in _clone_fn
#     res = _gen_core(text, lang, ref_aud, None, ns, gs, dn, sp, du, pp, po, mode="clone", ref_text=ref_text)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/app.py", line 253, in _gen_core
#     kw["voice_clone_prompt"] = model.create_voice_clone_prompt(ref_audio=ref_audio, ref_text=ref_text)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/OmniVoice/omnivoice/models/omnivoice.py", line 666, in create_voice_clone_prompt
#     ref_audio_tokens = self.audio_tokenizer.encode(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/higgs_audio_v2_tokenizer/modeling_higgs_audio_v2_tokenizer.py", line 549, in encode
#     e_acoustic = self.acoustic_encoder(input_values)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 467, in forward
#     hidden_state = module(hidden_state)
#                    ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 226, in forward
#     hidden_state = self.res_unit1(hidden_state)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 201, in forward
#     output_tensor = self.conv2(self.snake2(output_tensor))
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 97, in forward
#     hidden_states = hidden_states + (self.alpha + 1e-9).reciprocal() * torch.sin(self.alpha * hidden_states).pow(2)
#                                                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 1.06 GiB. GPU 0 has a total capacity of 14.56 GiB of which 261.81 MiB is free. Including non-PyTorch memory, this process has 14.30 GiB memory in use. Of the allocated memory 10.70 GiB is allocated by PyTorch, and 985.52 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 2026-04-05 17:42:28,523 omnivoice.models.omnivoice WARNING: Reference audio is 191.7s long (>20s) and ref_text was provided, so automatic trimming is skipped. A long reference may cause slower generation and degraded quality.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2191, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1698, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2518, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 1002, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/app.py", line 395, in _clone_fn
#     res = _gen_core(text, lang, ref_aud, None, ns, gs, dn, sp, du, pp, po, mode="clone", ref_text=ref_text)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/app.py", line 253, in _gen_core
#     kw["voice_clone_prompt"] = model.create_voice_clone_prompt(ref_audio=ref_audio, ref_text=ref_text)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/OmniVoice/omnivoice/models/omnivoice.py", line 666, in create_voice_clone_prompt
#     ref_audio_tokens = self.audio_tokenizer.encode(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/higgs_audio_v2_tokenizer/modeling_higgs_audio_v2_tokenizer.py", line 549, in encode
#     e_acoustic = self.acoustic_encoder(input_values)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 467, in forward
#     hidden_state = module(hidden_state)
#                    ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 226, in forward
#     hidden_state = self.res_unit1(hidden_state)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 201, in forward
#     output_tensor = self.conv2(self.snake2(output_tensor))
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 97, in forward
#     hidden_states = hidden_states + (self.alpha + 1e-9).reciprocal() * torch.sin(self.alpha * hidden_states).pow(2)
#                                                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 1.06 GiB. GPU 0 has a total capacity of 14.56 GiB of which 261.81 MiB is free. Including non-PyTorch memory, this process has 14.30 GiB memory in use. Of the allocated memory 10.70 GiB is allocated by PyTorch, and 985.52 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 2026-04-05 17:44:28,617 omnivoice.models.omnivoice DEBUG: Item 0 chunked into 14 pieces: ['The city does not sleep. It breathes. It calculates. It remembers every fracture, every compromise, every silent victory buried beneath concrete and glass.', 'We are told that progress moves in straight lines. That history advances through deliberate design. This is a fabrication. Progress moves in spirals. It returns to the same coordinates,', 'dressed in different light. I have watched it happen. I have documented the repetitions. And I have learned that truth does not announce itself. It accumulates.', 'You will meet individuals who claim certainty as a virtue. They will speak of inevitability. They will map the future with precision. Do not mistake confidence for clarity.', 'Certainty is often a defense against ambiguity. It is a structure built to contain doubt. The ones who survive are not the loudest.', 'They are the ones who listen to the spaces between the words. Who measure silence. Who understand that every decision carries a shadow.\n\nWhen the pressure mounts,', 'the architecture of routine fractures. Protocols fail. Alliances shift. The narratives we constructed begin to unravel. This is not a malfunction. This is the system operating as intended.', 'Chaos is not the absence of order. It is the redistribution of it. You will be asked to choose between preservation and adaptation. Between loyalty and necessity.', 'There is no correct answer. There is only consequence. And consequence does not negotiate.\n\nI will not offer you comfort. I will not provide closure on demand.', 'The final sequence will not resolve every variable. It will simply align them. You will witness the intersection of preparation and opportunity.', 'You will see what remains when the noise is stripped away. Do not look for heroes. Look for continuity.', 'Look for the individuals who refused to abandon their post when the parameters changed. They do not require recognition. They require execution.', 'The record will be written by those who remain. By those who understand that endurance is not passive. It is deliberate. It is calibrated.', 'It is the quiet accumulation of correct decisions, made under imperfect conditions. The cycle continues. The spiral tightens. And we proceed.']
# 2026-04-05 17:44:28,617 omnivoice.models.omnivoice DEBUG: Item 0 — text: The city does not sleep. It breathes. It calculates. It remembers every fracture, every compromise, every silent victory buried beneath concrete and glass. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 307
# 2026-04-05 17:44:33,318 omnivoice.models.omnivoice DEBUG: Item 0 — text: We are told that progress moves in straight lines. That history advances through deliberate design. This is a fabrication. Progress moves in spirals. It returns to the same coordinates, | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 366
# 2026-04-05 17:44:38,256 omnivoice.models.omnivoice DEBUG: Item 0 — text: dressed in different light. I have watched it happen. I have documented the repetitions. And I have learned that truth does not announce itself. It accumulates. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 315
# 2026-04-05 17:44:42,966 omnivoice.models.omnivoice DEBUG: Item 0 — text: You will meet individuals who claim certainty as a virtue. They will speak of inevitability. They will map the future with precision. Do not mistake confidence for clarity. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 340
# 2026-04-05 17:44:47,899 omnivoice.models.omnivoice DEBUG: Item 0 — text: Certainty is often a defense against ambiguity. It is a structure built to contain doubt. The ones who survive are not the loudest. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 256
# 2026-04-05 17:44:51,871 omnivoice.models.omnivoice DEBUG: Item 0 — text: They are the ones who listen to the spaces between the words. Who measure silence. Who understand that every decision carries a shadow.
#
# When the pressure mounts, | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 320
# 2026-04-05 17:44:56,680 omnivoice.models.omnivoice DEBUG: Item 0 — text: the architecture of routine fractures. Protocols fail. Alliances shift. The narratives we constructed begin to unravel. This is not a malfunction. This is the system operating as intended. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 374
# 2026-04-05 17:45:01,898 omnivoice.models.omnivoice DEBUG: Item 0 — text: Chaos is not the absence of order. It is the redistribution of it. You will be asked to choose between preservation and adaptation. Between loyalty and necessity. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 318
# 2026-04-05 17:45:06,754 omnivoice.models.omnivoice DEBUG: Item 0 — text: There is no correct answer. There is only consequence. And consequence does not negotiate.
#
# I will not offer you comfort. I will not provide closure on demand. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 312
# 2026-04-05 17:45:11,573 omnivoice.models.omnivoice DEBUG: Item 0 — text: The final sequence will not resolve every variable. It will simply align them. You will witness the intersection of preparation and opportunity. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 288
# 2026-04-05 17:45:16,205 omnivoice.models.omnivoice DEBUG: Item 0 — text: You will see what remains when the noise is stripped away. Do not look for heroes. Look for continuity. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 199
# 2026-04-05 17:45:19,838 omnivoice.models.omnivoice DEBUG: Item 0 — text: Look for the individuals who refused to abandon their post when the parameters changed. They do not require recognition. They require execution. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 288
# 2026-04-05 17:45:24,406 omnivoice.models.omnivoice DEBUG: Item 0 — text: The record will be written by those who remain. By those who understand that endurance is not passive. It is deliberate. It is calibrated. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 269
# 2026-04-05 17:45:28,893 omnivoice.models.omnivoice DEBUG: Item 0 — text: It is the quiet accumulation of correct decisions, made under imperfect conditions. The cycle continues. The spiral tightens. And we proceed. | ref_text: My name is Red Pepper. I'm a voiceover artist. In the UK, I've voiced hundreds of movie trailers. Men in Black. Saving the earth from the scum of the universe. | instruct: None | lang: None | target_tokens: 280
# 2026-04-05 18:09:38,298 omnivoice.models.omnivoice DEBUG: Item 0 chunked into 4 pieces: ['The city does not sleep. It breathes. It calculates. It remembers every fracture, every compromise, every silent victory buried beneath concrete and glass.', 'We are told that progress moves in straight lines. That history advances through deliberate design. This is a fabrication. Progress moves in spirals.', 'It returns to the same coordinates, dressed in different light. I have watched it happen. I have documented the repetitions.', 'And I have learned that truth does not announce itself. It accumulates.']
# 2026-04-05 18:09:38,298 omnivoice.models.omnivoice DEBUG: Item 0 — text: The city does not sleep. It breathes. It calculates. It remembers every fracture, every compromise, every silent victory buried beneath concrete and glass. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 344
# 2026-04-05 18:09:41,403 omnivoice.models.omnivoice DEBUG: Item 0 — text: We are told that progress moves in straight lines. That history advances through deliberate design. This is a fabrication. Progress moves in spirals. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 331
# 2026-04-05 18:09:44,463 omnivoice.models.omnivoice DEBUG: Item 0 — text: It returns to the same coordinates, dressed in different light. I have watched it happen. I have documented the repetitions. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 273
# 2026-04-05 18:09:47,150 omnivoice.models.omnivoice DEBUG: Item 0 — text: And I have learned that truth does not announce itself. It accumulates. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 156
# 2026-04-05 18:14:33,659 omnivoice.models.omnivoice DEBUG: Item 0 chunked into 18 pieces: ['Number one. Elon Musk. Net worth approximately two hundred forty five billion dollars. Primary sector. Technology, automotive manufacturing, and aerospace.', 'Key enterprises include Tesla and SpaceX. Number two. Bernard Arnault and family. Net worth approximately one hundred ninety eight billion dollars. Primary sector.', 'Luxury goods and retail. Key enterprise is LVMH. Number three. Jeff Bezos. Net worth approximately one hundred eighty two billion dollars. Primary sector.', 'E-commerce and cloud computing. Key enterprise is Amazon. Number four. Mark Zuckerberg. Net worth approximately one hundred seventy five billion dollars.', 'Primary sector. Technology and social media. Key enterprise is Meta Platforms. Number five. Larry Ellison. Net worth approximately one hundred sixty billion dollars.', 'Primary sector. Enterprise software and cloud infrastructure. Key enterprise is Oracle. Number six. Warren Buffett.', 'Net worth approximately one hundred thirty two billion dollars. Primary sector. Diversified investments and insurance. Key enterprise is Berkshire Hathaway.', 'Number seven. Bill Gates. Net worth approximately one hundred twenty eight billion dollars. Primary sector. Technology and philanthropy.', 'Key holdings include Microsoft equity and Cascade Investment. Number eight. Steve Ballmer. Net worth approximately one hundred twenty four billion dollars.', 'Primary sector. Technology investments and sports ownership. Key holdings include Microsoft equity and the Los Angeles Clippers franchise. Number nine. Larry Page.', 'Net worth approximately one hundred eighteen billion dollars. Primary sector. Technology and digital services. Key enterprise is Alphabet. Number ten. Sergey Brin.', 'Net worth approximately one hundred fourteen billion dollars. Primary sector. Technology and digital services. Key enterprise is Alphabet. Number eleven.', 'Mukesh Ambani. Net worth approximately one hundred ten billion dollars. Primary sector. Petrochemicals, telecommunications, and retail.', 'Key enterprise is Reliance Industries. Number twelve. Francoise Bettencourt Meyers. Net worth approximately one hundred five billion dollars. Primary sector.', "Luxury cosmetics and consumer goods. Key holding is L'Oréal. Number thirteen. Zhong Shanshan. Net worth approximately ninety eight billion dollars. Primary sector.", 'Beverages and pharmaceuticals. Key enterprises include Nongfu Spring and Beijing Wantai Biological. Number fourteen. Carlos Slim Helu.', 'Net worth approximately ninety three billion dollars. Primary sector. Telecommunications and diversified investments. Key enterprise is América Móvil.', 'Number fifteen. Michael Bloomberg.']
# 2026-04-05 18:14:33,660 omnivoice.models.omnivoice DEBUG: Item 0 — text: Number one. Elon Musk. Net worth approximately two hundred forty five billion dollars. Primary sector. Technology, automotive manufacturing, and aerospace. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 348
# 2026-04-05 18:14:36,831 omnivoice.models.omnivoice DEBUG: Item 0 — text: Key enterprises include Tesla and SpaceX. Number two. Bernard Arnault and family. Net worth approximately one hundred ninety eight billion dollars. Primary sector. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 365
# 2026-04-05 18:14:40,095 omnivoice.models.omnivoice DEBUG: Item 0 — text: Luxury goods and retail. Key enterprise is LVMH. Number three. Jeff Bezos. Net worth approximately one hundred eighty two billion dollars. Primary sector. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 341
# 2026-04-05 18:14:43,269 omnivoice.models.omnivoice DEBUG: Item 0 — text: E-commerce and cloud computing. Key enterprise is Amazon. Number four. Mark Zuckerberg. Net worth approximately one hundred seventy five billion dollars. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 343
# 2026-04-05 18:14:46,454 omnivoice.models.omnivoice DEBUG: Item 0 — text: Primary sector. Technology and social media. Key enterprise is Meta Platforms. Number five. Larry Ellison. Net worth approximately one hundred sixty billion dollars. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 369
# 2026-04-05 18:14:49,761 omnivoice.models.omnivoice DEBUG: Item 0 — text: Primary sector. Enterprise software and cloud infrastructure. Key enterprise is Oracle. Number six. Warren Buffett. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 259
# 2026-04-05 18:14:52,238 omnivoice.models.omnivoice DEBUG: Item 0 — text: Net worth approximately one hundred thirty two billion dollars. Primary sector. Diversified investments and insurance. Key enterprise is Berkshire Hathaway. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 355
# 2026-04-05 18:14:55,438 omnivoice.models.omnivoice DEBUG: Item 0 — text: Number seven. Bill Gates. Net worth approximately one hundred twenty eight billion dollars. Primary sector. Technology and philanthropy. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 306
# 2026-04-05 18:14:58,315 omnivoice.models.omnivoice DEBUG: Item 0 — text: Key holdings include Microsoft equity and Cascade Investment. Number eight. Steve Ballmer. Net worth approximately one hundred twenty four billion dollars. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 350
# 2026-04-05 18:15:01,449 omnivoice.models.omnivoice DEBUG: Item 0 — text: Primary sector. Technology investments and sports ownership. Key holdings include Microsoft equity and the Los Angeles Clippers franchise. Number nine. Larry Page. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 367
# 2026-04-05 18:15:04,664 omnivoice.models.omnivoice DEBUG: Item 0 — text: Net worth approximately one hundred eighteen billion dollars. Primary sector. Technology and digital services. Key enterprise is Alphabet. Number ten. Sergey Brin. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 366
# 2026-04-05 18:15:07,871 omnivoice.models.omnivoice DEBUG: Item 0 — text: Net worth approximately one hundred fourteen billion dollars. Primary sector. Technology and digital services. Key enterprise is Alphabet. Number eleven. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 346
# 2026-04-05 18:15:10,970 omnivoice.models.omnivoice DEBUG: Item 0 — text: Mukesh Ambani. Net worth approximately one hundred ten billion dollars. Primary sector. Petrochemicals, telecommunications, and retail. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 307
# 2026-04-05 18:15:13,799 omnivoice.models.omnivoice DEBUG: Item 0 — text: Key enterprise is Reliance Industries. Number twelve. Francoise Bettencourt Meyers. Net worth approximately one hundred five billion dollars. Primary sector. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 356
# 2026-04-05 18:15:16,915 omnivoice.models.omnivoice DEBUG: Item 0 — text: Luxury cosmetics and consumer goods. Key holding is L'Oréal. Number thirteen. Zhong Shanshan. Net worth approximately ninety eight billion dollars. Primary sector. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 365
# 2026-04-05 18:15:20,095 omnivoice.models.omnivoice DEBUG: Item 0 — text: Beverages and pharmaceuticals. Key enterprises include Nongfu Spring and Beijing Wantai Biological. Number fourteen. Carlos Slim Helu. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 305
# 2026-04-05 18:15:22,891 omnivoice.models.omnivoice DEBUG: Item 0 — text: Net worth approximately ninety three billion dollars. Primary sector. Telecommunications and diversified investments. Key enterprise is América Móvil. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 344
# 2026-04-05 18:15:25,919 omnivoice.models.omnivoice DEBUG: Item 0 — text: Number fifteen. Michael Bloomberg. | ref_text: All stations to Harrow, mind the doors. | instruct: None | lang: None | target_tokens: 78
# 2026-04-05 19:28:58,760 omnivoice.models.omnivoice WARNING: Reference audio is 256.9s long (>20s) and ref_text was provided, so automatic trimming is skipped. A long reference may cause slower generation and degraded quality.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2191, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1698, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2518, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 1002, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/app.py", line 395, in _clone_fn
#     res = _gen_core(text, lang, ref_aud, None, ns, gs, dn, sp, du, pp, po, mode="clone", ref_text=ref_text)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/app.py", line 253, in _gen_core
#     kw["voice_clone_prompt"] = model.create_voice_clone_prompt(ref_audio=ref_audio, ref_text=ref_text)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/OmniVoice/omnivoice/models/omnivoice.py", line 666, in create_voice_clone_prompt
#     ref_audio_tokens = self.audio_tokenizer.encode(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/higgs_audio_v2_tokenizer/modeling_higgs_audio_v2_tokenizer.py", line 549, in encode
#     e_acoustic = self.acoustic_encoder(input_values)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 467, in forward
#     hidden_state = module(hidden_state)
#                    ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 226, in forward
#     hidden_state = self.res_unit1(hidden_state)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 200, in forward
#     output_tensor = self.conv1(self.snake1(output_tensor))
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 97, in forward
#     hidden_states = hidden_states + (self.alpha + 1e-9).reciprocal() * torch.sin(self.alpha * hidden_states).pow(2)
#                     ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 1.45 GiB. GPU 0 has a total capacity of 14.56 GiB of which 1.08 GiB is free. Including non-PyTorch memory, this process has 13.48 GiB memory in use. Of the allocated memory 9.53 GiB is allocated by PyTorch, and 1.31 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 2026-04-05 19:33:04,794 omnivoice.models.omnivoice WARNING: Reference audio is 83.8s long (>20s) and ref_text was provided, so automatic trimming is skipped. A long reference may cause slower generation and degraded quality.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2191, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1698, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2518, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 1002, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/app.py", line 395, in _clone_fn
#     res = _gen_core(text, lang, ref_aud, None, ns, gs, dn, sp, du, pp, po, mode="clone", ref_text=ref_text)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/app.py", line 253, in _gen_core
#     kw["voice_clone_prompt"] = model.create_voice_clone_prompt(ref_audio=ref_audio, ref_text=ref_text)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/omnivoice-colab/OmniVoice/omnivoice/models/omnivoice.py", line 666, in create_voice_clone_prompt
#     ref_audio_tokens = self.audio_tokenizer.encode(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/higgs_audio_v2_tokenizer/modeling_higgs_audio_v2_tokenizer.py", line 549, in encode
#     e_acoustic = self.acoustic_encoder(input_values)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 467, in forward
#     hidden_state = module(hidden_state)
#                    ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 227, in forward
#     hidden_state = self.res_unit2(hidden_state)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 201, in forward
#     output_tensor = self.conv2(self.snake2(output_tensor))
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/dac/modeling_dac.py", line 97, in forward
#     hidden_states = hidden_states + (self.alpha + 1e-9).reciprocal() * torch.sin(self.alpha * hidden_states).pow(2)
#                                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 484.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 469.81 MiB is free. Including non-PyTorch memory, this process has 14.10 GiB memory in use. Of the allocated memory 11.01 GiB is allocated by PyTorch, and 459.99 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 2026-04-05 19:34:07,383 omnivoice.models.omnivoice WARNING: Reference audio is 21.3s long (>20s) and ref_text was provided, so automatic trimming is skipped. A long reference may cause slower generation and degraded quality.
# 2026-04-05 19:34:07,501 omnivoice.models.omnivoice DEBUG: Item 0 — text: The city does not sleep. It breathes. It calculates. It remembers every fracture, every compromise, every silent victory buried beneath concrete and glass. We are told that progress moves in straight lines. That history advances through deliberate design. This is a fabrication. Progress moves in spirals. It returns to the same coordinates, dressed in different light. I have watched it happen. I have documented the repetitions. And I have learned that truth does not announce itself. It accumulates. | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 747
# 2026-04-05 19:36:01,776 omnivoice.models.omnivoice WARNING: Reference audio is 21.3s long (>20s) and ref_text was provided, so automatic trimming is skipped. A long reference may cause slower generation and degraded quality.
# 2026-04-05 19:36:01,846 omnivoice.models.omnivoice DEBUG: Item 0 chunked into 17 pieces: ['Welcome to the definitive wealth countdown. Today, we are looking at the movers, the shakers, and the visionaries who define the global economy. These are the Top 20 Richest People on Earth as of 2026. Let’s start the clock.', "Kicking off at number 20 is Francoise Bettencourt Meyers. The world’s wealthiest woman continues to oversee the L'Oréal empire, blending heritage with modern cosmetics dominance.\n\nAt 19, Bill Gates. No longer just a software pioneer,", 'Gates has redirected his billions into climate tech and aggressive global health initiatives through his foundation.\n\nNumber 18, Michael Bloomberg. The architect of the financial world’s data nervous system.', 'His media and tech empire remains the gold standard for global markets.\n\nComing in at 17 is C-Z. Despite the volatility of the crypto era, he built Binance into a global powerhouse that survived the storm and defined the digital asset space.', 'At 16, Mexico’s Carlos Slim Helu. A titan of telecommunications, his influence spans across Latin America’s entire infrastructure and mobile network.\n\nNumber 15, Steve Ballmer. From Microsoft CEO to the high-energy owner of the LA Clippers,', 'Ballmer’s wealth continues to climb alongside his tech investments.\n\nAt 14, Alice Walton. While her wealth stems from the Walmart legacy, she has carved her own path as a premier patron of American art and curation.\n\nNumber 13, Michael Dell.', 'A true dorm-room-to-boardroom story. Dell Technologies remains a cornerstone of the global hardware and enterprise infrastructure.\n\nAt 12, Jim Walton. As the youngest son of Sam Walton,', 'his leadership at Arvest Bank has solidified his place among the world’s financial elite.\n\nJust missing the top ten at 11 is Rob Walton.', 'The eldest Walton sibling has played a massive role in overseeing the global retail dominance of the Walmart brand.\n\nEntering the Top 10, Amancio Ortega. The founder of Zara revolutionized fast fashion,', 'proving that logistics and retail speed are the keys to a billion-dollar empire.\n\nAt number 9, the Oracle of Omaha, Warren Buffett. The world’s greatest value investor continues to prove that patience and compounding are the ultimate weapons.', 'Number 8, Jensen Huang. The face of the AI revolution. His leadership at Nvidia has made him the most important individual in the hardware that powers our future.\n\nAt 7, the king of luxury, Bernard Arnault. From Louis Vuitton to Sephora,', 'his LVMH group controls the most prestigious brands in human history.\n\nComing in at 6, Larry Ellison. The Oracle founder is a cloud pioneer whose massive database empire has allowed him to literally own Hawaiian islands.\n\nEntering the Top 5,', 'Mark Zuckerberg. By pivoting Meta into AI and immersive reality, he has regained his position as a primary architect of the social future.\n\nAt number 4, Jeff Bezos. While Amazon remains a juggernaut, Bezos is now looking toward the stars,', 'investing heavily in the commercialization of space.\n\nTaking the Bronze at 3, Sergey Brin. The Google co-founder has shifted his focus from search engines to high-altitude airships and next-gen tech ventures.\n\nThe Runner Up at number 2,', 'Larry Page. He remains at the forefront of innovation, backing everything from flying cars to the most advanced AI models on earth.\n\nAnd at Number 1, Elon Musk. With a net worth nearing a trillion dollars, his dominance in EVs, space flight,', 'and artificial intelligence remains completely unmatched in 2026.\n\nThat’s the Titan Index for 2026. In a world defined by rapid innovation, these are the individuals holding the keys. Who do you think will climb the list next year?', 'Let us know in the comments. Thanks for watching.']
# 2026-04-05 19:36:01,846 omnivoice.models.omnivoice DEBUG: Item 0 — text: Welcome to the definitive wealth countdown. Today, we are looking at the movers, the shakers, and the visionaries who define the global economy. These are the Top 20 Richest People on Earth as of 2026. Let’s start the clock. | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 353
# 2026-04-05 19:36:09,753 omnivoice.models.omnivoice DEBUG: Item 0 — text: Kicking off at number 20 is Francoise Bettencourt Meyers. The world’s wealthiest woman continues to oversee the L'Oréal empire, blending heritage with modern cosmetics dominance.
#
# At 19, Bill Gates. No longer just a software pioneer, | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 367
# 2026-04-05 19:36:17,694 omnivoice.models.omnivoice DEBUG: Item 0 — text: Gates has redirected his billions into climate tech and aggressive global health initiatives through his foundation.
#
# Number 18, Michael Bloomberg. The architect of the financial world’s data nervous system. | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 324
# 2026-04-05 19:36:24,966 omnivoice.models.omnivoice DEBUG: Item 0 — text: His media and tech empire remains the gold standard for global markets.
#
# Coming in at 17 is C-Z. Despite the volatility of the crypto era, he built Binance into a global powerhouse that survived the storm and defined the digital asset space. | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 365
# 2026-04-05 19:36:32,740 omnivoice.models.omnivoice DEBUG: Item 0 — text: At 16, Mexico’s Carlos Slim Helu. A titan of telecommunications, his influence spans across Latin America’s entire infrastructure and mobile network.
#
# Number 15, Steve Ballmer. From Microsoft CEO to the high-energy owner of the LA Clippers, | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 376
# 2026-04-05 19:36:40,458 omnivoice.models.omnivoice DEBUG: Item 0 — text: Ballmer’s wealth continues to climb alongside his tech investments.
#
# At 14, Alice Walton. While her wealth stems from the Walmart legacy, she has carved her own path as a premier patron of American art and curation.
#
# Number 13, Michael Dell. | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 375
# 2026-04-05 19:36:48,094 omnivoice.models.omnivoice DEBUG: Item 0 — text: A true dorm-room-to-boardroom story. Dell Technologies remains a cornerstone of the global hardware and enterprise infrastructure.
#
# At 12, Jim Walton. As the youngest son of Sam Walton, | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 286
# 2026-04-05 19:36:54,606 omnivoice.models.omnivoice DEBUG: Item 0 — text: his leadership at Arvest Bank has solidified his place among the world’s financial elite.
#
# Just missing the top ten at 11 is Rob Walton. | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 210
# 2026-04-05 19:37:00,543 omnivoice.models.omnivoice DEBUG: Item 0 — text: The eldest Walton sibling has played a massive role in overseeing the global retail dominance of the Walmart brand.
#
# Entering the Top 10, Amancio Ortega. The founder of Zara revolutionized fast fashion, | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 312
# 2026-04-05 19:37:07,402 omnivoice.models.omnivoice DEBUG: Item 0 — text: proving that logistics and retail speed are the keys to a billion-dollar empire.
#
# At number 9, the Oracle of Omaha, Warren Buffett. The world’s greatest value investor continues to prove that patience and compounding are the ultimate weapons. | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 366
# 2026-04-05 19:37:14,860 omnivoice.models.omnivoice DEBUG: Item 0 — text: Number 8, Jensen Huang. The face of the AI revolution. His leadership at Nvidia has made him the most important individual in the hardware that powers our future.
#
# At 7, the king of luxury, Bernard Arnault. From Louis Vuitton to Sephora, | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 357
# 2026-04-05 19:37:22,339 omnivoice.models.omnivoice DEBUG: Item 0 — text: his LVMH group controls the most prestigious brands in human history.
#
# Coming in at 6, Larry Ellison. The Oracle founder is a cloud pioneer whose massive database empire has allowed him to literally own Hawaiian islands.
#
# Entering the Top 5, | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 369
# 2026-04-05 19:37:29,931 omnivoice.models.omnivoice DEBUG: Item 0 — text: Mark Zuckerberg. By pivoting Meta into AI and immersive reality, he has regained his position as a primary architect of the social future.
#
# At number 4, Jeff Bezos. While Amazon remains a juggernaut, Bezos is now looking toward the stars, | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 357
# 2026-04-05 19:37:37,484 omnivoice.models.omnivoice DEBUG: Item 0 — text: investing heavily in the commercialization of space.
#
# Taking the Bronze at 3, Sergey Brin. The Google co-founder has shifted his focus from search engines to high-altitude airships and next-gen tech ventures.
#
# The Runner Up at number 2, | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 362
# 2026-04-05 19:37:45,106 omnivoice.models.omnivoice DEBUG: Item 0 — text: Larry Page. He remains at the forefront of innovation, backing everything from flying cars to the most advanced AI models on earth.
#
# And at Number 1, Elon Musk. With a net worth nearing a trillion dollars, his dominance in EVs, space flight, | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 358
# 2026-04-05 19:37:52,731 omnivoice.models.omnivoice DEBUG: Item 0 — text: and artificial intelligence remains completely unmatched in 2026.
#
# That’s the Titan Index for 2026. In a world defined by rapid innovation, these are the individuals holding the keys. Who do you think will climb the list next year? | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 378
# 2026-04-05 19:38:00,447 omnivoice.models.omnivoice DEBUG: Item 0 — text: Let us know in the comments. Thanks for watching. | ref_text: new one. So for this one, for example, you know, I like this shot and the house is pretty cool, but I kind of want there to be a golf course on those cliffs in the background, right? So I type that and then I can also change the resolution, which as you can see, it will take longer for higher resolutions. And then you also can specify exactly how much of a remix it is. | instruct: None | lang: None | target_tokens: 71
